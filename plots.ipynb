# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('result.csv')
df
# Out:
#     Percent_flooding   Inter arrival time   mining_power_utilization  \
# 0                 10                    2                   0.680370
# 1                 10                    4                   0.835971
# 2                 10                    6                   0.888489
# 3                 10                    8                   0.920833
# 4                 10                   10                   0.935644
# 5                 20                    2                   0.732571
# 6                 20                    4                   0.898333
# 7                 20                    6                   0.902214
# 8                 20                    8                   0.920892
# 9                 20                   10                   0.959698
# 10                30                    2                   0.731680
# 11                30                    4                   0.891269
# 12                30                    6                   0.934653
# 13                30                    8                   0.932886
# 14                30                   10                   0.947500
#
#     fraction_adversary
# 0             0.460030
# 1             0.432990
# 2             0.468687
# 3             0.442438
# 4             0.546174
# 5             0.595016
# 6             0.544444
# 7             0.448980
# 8             0.408791
# 9             0.570681
# 10            0.589231
# 11            0.487085
# 12            0.501057
# 13            0.562201
# 14            0.528947

# %%
for key, grp in df.groupby(df.columns[0]):
    plt.plot(grp[df.columns[1]], grp[df.columns[2]], label=key)

plt.title('Mining Power Utilization')
plt.xlabel(df.columns[1])
plt.ylabel(df.columns[2])
plt.legend(title=df.columns[0])
plt.show()

# %%
for key, grp in df.groupby(df.columns[0]):
    plt.plot(grp[df.columns[1]], grp[df.columns[3]], label=key)

plt.title('Fraction Mined by Adversary')
plt.xlabel(df.columns[1])
plt.ylabel(df.columns[3])
plt.legend(title=df.columns[0])
plt.show()
